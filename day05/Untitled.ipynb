# %% [raw]
# # 과일가게 재고 프로그램 구축
#
# # 1. 기능
# # 과일 입력(I), 과일 판매(S), 재고 리스트(L), 삭제(D)
# #-괄호 안 영문자를 입력하면 각 기능이 구현되게 만든다
#
# # 2. 입력(I)
# # -dictionary로 각 키의 값을 받고 빈 리스트에 채워나간다.
# # -입고일자(date):8자리로 입력해야함
# #  ->Len 값으로 입력 값의 길이를 구함
# #  ->4자리가 아닐 경우 재입력 하도록 함
# # -당도(sweet):1~5사이의 값만 입력해야함
# # -키 값 입력이 완료된 fruit 딕셔너리를 fruitlist에 추가(append)한다.
# # - 상품명, 수량, 단가, 입고일자
#
# # 3. 판매(S)
#
# # 4. 재고리스트(L)
# # product, stock, price, date, sweet 에 따라 정렬 가능하게 한다
# .
# # 5. 삭제(D)
# # 수량이 0이 된 품목을 표시한다.

# %%
import re

fruitlist=[]
fruitlist=[{'product': '사과', 'stock': '20', 'price': '1000', 'date': '20220510', 'sweet':'4'},
           {'product': '바나나', 'stock': '15', 'price': '500', 'date': '20220508', 'sweet':'2'},
           {'product': '토마토', 'stock': '25', 'price': '1500', 'date': '20220506', 'sweet':'3'}]

while True:
    choice=input('''
다음 중에서 하실 일을 골라주세요 :
I - 입력 \t S - 판매 \t L- 재고 리스트 \t D-삭제
>>> ''').upper()
    if choice == 'I':
        print(fruitlist)
        L = {'fruit':'','stock':'','price':'','date':'','sweet':''}
        L['fruit'] = input('추가할 과일명을 입력하세요 >>>')
        stock ='a'
        while not L['stock'].isdecimal():
            stock = input('추가할 수량를 입력하세요 >>>')
            break
        L['stock']=int(stock)
        price = 'b'
        while not L['price'].isdecimal():
            price = input('가격을 입력하세요 >>>')
            break
        L['price']=int(price)
        date = 'c'
        while not len(date) == 8 and L['date'].isdecimal():
            date = input('입고일자 8자리를 입력하세요 >>> ')
            break
        L['date']=int(date)
        sweet = 'd'
        while not L['sweet'].isdecimal():
            sweet = input('과일의 당도를 입력하세요 >>> ')
            break
        L['sweet']=int(sweet)
        fruitlist.append(L)
        print(fruitlist)

    # if choice == 'S':
    #     productlist = []
    #     for item in fruitlist:
    #         print(item['product'])
    #         productlist.append(item['product'])

    #     product = input('팔린 물품을 입력하세요 \t(종료: Enter)')
    #     while :
    #         if item['product'] in productlist:
    #             break         
    #         count = 'a'
    #         while not count.isdecimal():
    #             count = input('팔린 수량을 입력하세요 \t남은 수량 \t(종료:Enter)')
